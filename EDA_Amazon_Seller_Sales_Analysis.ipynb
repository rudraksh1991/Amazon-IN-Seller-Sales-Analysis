# %%
#Import Packages
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Import Data
seller_sales_data=pd.read_excel(r'D:\Amazon_Project\EDA_Amazon_Seller_Sales_Analysis\amazon_seller_order_sample_data.xlsx')

# %%
#let us understand the data!
seller_sales_data.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# 1  Women's Set of 5 Multicolor Pure Leather Singl...         1    ₹449.00
# 2  Women's Set of 5 Multicolor Pure Leather Singl...         1    ₹449.00
# 3  Pure 100% Leather Block Print Rectangular Jewe...         1        NaN
# 4  Pure Leather Sling Bag with Multiple Pockets a...         1  ₹1,099.00
#
#   shipping_fee               cod        order_status
# 0          NaN               NaN  Delivered to buyer
# 1       ₹60.18               NaN  Delivered to buyer
# 2       ₹60.18               NaN  Delivered to buyer
# 3          NaN  Cash On Delivery  Delivered to buyer
# 4       ₹84.96               NaN  Delivered to buyer

# %%
seller_sales_data.describe(include="all")
# Out:
#                    order_no                       order_date    buyer  \
# count                   171                              171      171
# unique                  171                              171      149
# top     405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST  Geetika
# freq                      1                                1        3
# mean                    NaN                              NaN      NaN
# std                     NaN                              NaN      NaN
# min                     NaN                              NaN      NaN
# 25%                     NaN                              NaN      NaN
# 50%                     NaN                              NaN      NaN
# 75%                     NaN                              NaN      NaN
# max                     NaN                              NaN      NaN
#
#        ship_city   ship_state                 sku  \
# count        171          171                 171
# unique        81           30                  54
# top      MUMBAI,  MAHARASHTRA  SKU:  DN-0WDX-VYOT
# freq          17           31                  33
# mean         NaN          NaN                 NaN
# std          NaN          NaN                 NaN
# min          NaN          NaN                 NaN
# 25%          NaN          NaN                 NaN
# 50%          NaN          NaN                 NaN
# 75%          NaN          NaN                 NaN
# max          NaN          NaN                 NaN
#
#                                               description    quantity  \
# count                                                 171  171.000000
# unique                                                 61         NaN
# top     Women's Set of 5 Multicolor Pure Leather Singl...         NaN
# freq                                                   33         NaN
# mean                                                  NaN    1.087719
# std                                                   NaN    0.445132
# min                                                   NaN    1.000000
# 25%                                                   NaN    1.000000
# 50%                                                   NaN    1.000000
# 75%                                                   NaN    1.000000
# max                                                   NaN    4.000000
#
#        item_total shipping_fee               cod        order_status
# count         153          145                47                 171
# unique         18           13                 1                   2
# top       ₹449.00       ₹84.96  Cash On Delivery  Delivered to buyer
# freq           52          100                47                 160
# mean          NaN          NaN               NaN                 NaN
# std           NaN          NaN               NaN                 NaN
# min           NaN          NaN               NaN                 NaN
# 25%           NaN          NaN               NaN                 NaN
# 50%           NaN          NaN               NaN                 NaN
# 75%           NaN          NaN               NaN                 NaN
# max           NaN          NaN               NaN                 NaN

# %%
#There are 171 datapoints and 12 features
#order_no and date are unique
#One buyer made at most 3 orders
#City,state, sku and description need further analysis
#The ordered quantity is at most 4 but median is 1
#Item_total and shipping_fee should be converted to float
#Cash on delivery has only 1 value, so it seems like boolean
#Order status is target variable, and has 2 classes.

# %%
seller_sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_no      171 non-null    object
#  1   order_date    171 non-null    object
#  2   buyer         171 non-null    object
#  3   ship_city     171 non-null    object
#  4   ship_state    171 non-null    object
#  5   sku           171 non-null    object
#  6   description   171 non-null    object
#  7   quantity      171 non-null    int64
#  8   item_total    153 non-null    object
#  9   shipping_fee  145 non-null    object
#  10  cod           47 non-null     object
#  11  order_status  171 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 16.2+ KB

# %%
[features for features in seller_sales_data.columns if seller_sales_data[features].isnull().sum()>0]
# Out:
# ['item_total', 'shipping_fee', 'cod']

# %%
#item_total, shipping_fee and cod has missing values, we should deal with them
#Order_data should be date dtype
#Item_total and Shipping_fee should be float or int
#COD should be boolean
#Order_status is also should be boolean

# %%
#Data Cleaning
seller_sales_data["order_date"]= pd.to_datetime(seller_sales_data['order_date'])
seller_sales_data["order_year"]=seller_sales_data["order_date"].dt.year
seller_sales_data["order_month"]=seller_sales_data["order_date"].dt.month
seller_sales_data['order_week'] = seller_sales_data['order_date'].dt.week
seller_sales_data["order_day"]=seller_sales_data["order_date"].dt.day

seller_sales_data['order_weekday'] = seller_sales_data['order_date'].dt.weekday

seller_sales_data['order_time'] = seller_sales_data['order_date'].dt.time
seller_sales_data['order_date_extracted'] = seller_sales_data['order_date'].dt.date

seller_sales_data.drop("order_date",axis=1,inplace=True)

# %%
# removing comma from city and state and make it upper case
locations = ['ship_city', 'ship_state']
for i in locations:
    seller_sales_data[i] = seller_sales_data[i].apply(lambda x: x.replace(',', '').upper())

# %%
seller_sales_data["buyer"]= seller_sales_data["buyer"].apply(lambda x: x.upper())

# %%
seller_sales_data["sku"] = seller_sales_data["sku"].apply(lambda x: x[5:])
seller_sales_data["sku"]=seller_sales_data["sku"].str.replace('-',"")
seller_sales_data["sku"]=seller_sales_data["sku"].apply(lambda x: x.replace(' ', ''))

# %%
# remove rupee symbol and commas from amount features
amounts = ['item_total', 'shipping_fee']
for i in amounts:
    seller_sales_data[i]=pd.to_numeric(seller_sales_data[i].str.replace(',',"").str.extract(r'([\d]+\.[\d]+)')[0])

# %%
#Data Imputation/Finding outliars
#The method of payment should be cash on delivery otherwise online.
seller_sales_data["cod"].fillna("Online",inplace=True)

# %%
#There are still some null values in item_total and shipping_fee

plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.violinplot(x=seller_sales_data.item_total)
plt.subplot(1,2,2)
sns.violinplot(x=seller_sales_data.shipping_fee)
# Out:
# <AxesSubplot:xlabel='shipping_fee'>

# %%
#The data is right skewed and there are some outliers.
#We should use median instead of mean by doing imputation.
#Median will be less prone to outliers.

# %%
#Exploratory Analysis of Data
seller_sales_data.describe(include="all")
# Out:
#                    order_no    buyer ship_city   ship_state         sku  \
# count                   171      171       171          171         171
# unique                  171      147        74           26          54
# top     405-9763961-5211537  GEETIKA    MUMBAI  MAHARASHTRA  DN0WDXVYOT
# freq                      1        3        20           32          33
# mean                    NaN      NaN       NaN          NaN         NaN
# std                     NaN      NaN       NaN          NaN         NaN
# min                     NaN      NaN       NaN          NaN         NaN
# 25%                     NaN      NaN       NaN          NaN         NaN
# 50%                     NaN      NaN       NaN          NaN         NaN
# 75%                     NaN      NaN       NaN          NaN         NaN
# max                     NaN      NaN       NaN          NaN         NaN
#
#                                               description    quantity  \
# count                                                 171  171.000000
# unique                                                 61         NaN
# top     Women's Set of 5 Multicolor Pure Leather Singl...         NaN
# freq                                                   33         NaN
# mean                                                  NaN    1.087719
# std                                                   NaN    0.445132
# min                                                   NaN    1.000000
# 25%                                                   NaN    1.000000
# 50%                                                   NaN    1.000000
# 75%                                                   NaN    1.000000
# max                                                   NaN    4.000000
#
#          item_total  shipping_fee     cod        order_status   order_year  \
# count    153.000000    145.000000     171                 171   171.000000
# unique          NaN           NaN       2                   2          NaN
# top             NaN           NaN  Online  Delivered to buyer          NaN
# freq            NaN           NaN     124                 160          NaN
# mean     582.856209     84.748414     NaN                 NaN  2021.187135
# std      488.100122     26.562623     NaN                 NaN     0.391165
# min      175.000000     47.200000     NaN                 NaN  2021.000000
# 25%      399.000000     84.960000     NaN                 NaN  2021.000000
# 50%      449.000000     84.960000     NaN                 NaN  2021.000000
# 75%      549.000000     84.960000     NaN                 NaN  2021.000000
# max     3897.000000    241.900000     NaN                 NaN  2022.000000
#
#         order_month  order_week   order_day  order_weekday order_time  \
# count    171.000000  171.000000  171.000000     171.000000        171
# unique          NaN         NaN         NaN            NaN        154
# top             NaN         NaN         NaN            NaN   20:53:00
# freq            NaN         NaN         NaN            NaN          2
# mean       8.426901   35.058480   15.561404       3.052632        NaN
# std        3.746242   15.763214    8.989571       1.997832        NaN
# min        1.000000    1.000000    1.000000       0.000000        NaN
# 25%        7.000000   30.000000    8.500000       2.000000        NaN
# 50%       10.000000   40.000000   16.000000       3.000000        NaN
# 75%       11.000000   47.000000   23.000000       5.000000        NaN
# max       12.000000   52.000000   31.000000       6.000000        NaN
#
#        order_date_extracted
# count                   171
# unique                  117
# top              2021-12-04
# freq                      4
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
#Sales based on cities and states
plt.figure(figsize=(20,6))

ax1 = plt.subplot(1, 2, 1)
plt.title("total sales of items by states")
data_ship_state=seller_sales_data.groupby("ship_state").aggregate("sum").sort_values("item_total",ascending=False)
sns.barplot(y=data_ship_state.index,x=data_ship_state["item_total"])

ax2 = plt.subplot(1,2,2)
plt.title("total quantity of sales by states")
data_ship_state=seller_sales_data.groupby("ship_state").aggregate("sum").sort_values("quantity",ascending=False)
sns.barplot(y=data_ship_state.index,x=data_ship_state["quantity"])
# Out:
# <AxesSubplot:title={'center':'total quantity of sales by states'}, xlabel='quantity', ylabel='ship_state'>

# %%
#Item_total: Top 5 cities : Uttar Pradesh, Mahasrashtra, West Bengal, Tamil Nadu, and Karnataka 
#Total Quantity of Orders: Top 5 cities Mahasrashtra, West Bengal, Tamil Nadu, Karnataka and Telangana
#The two charts are almost alike which is normal, more quantity of item yields more sales (Item_total)

# %%
seller_sales_data.head(5)
# Out:
#               order_no       buyer    ship_city         ship_state  \
# 0  405-9763961-5211537         MR.   CHANDIGARH         CHANDIGARH
# 1  404-3964908-7850720       MINAM     PASIGHAT  ARUNACHAL PRADESH
# 2  171-8103182-4289117  YATIPERTIN     PASIGHAT  ARUNACHAL PRADESH
# 3  405-3171677-9557154       ACIYA  DEVARAKONDA          TELANGANA
# 4  402-8910771-1215552     SUSMITA       MUMBAI        MAHARASHTRA
#
#           sku                                        description  quantity  \
# 0  2X3C0FKNJE  100% Leather Elephant Shaped Piggy Coin Bank |...         1
# 1  DN0WDXVYOT  Women's Set of 5 Multicolor Pure Leather Singl...         1
# 2  DN0WDXVYOT  Women's Set of 5 Multicolor Pure Leather Singl...         1
# 3  AHJ3AOR7DN  Pure 100% Leather Block Print Rectangular Jewe...         1
# 4  KL7WAAZ82I  Pure Leather Sling Bag with Multiple Pockets a...         1
#
#    item_total  shipping_fee               cod        order_status  order_year  \
# 0       449.0           NaN            Online  Delivered to buyer        2021
# 1       449.0         60.18            Online  Delivered to buyer        2021
# 2       449.0         60.18            Online  Delivered to buyer        2021
# 3         NaN           NaN  Cash On Delivery  Delivered to buyer        2021
# 4      1099.0         84.96            Online  Delivered to buyer        2021
#
#    order_month  order_week  order_day  order_weekday order_time  \
# 0            7          28         18              6   22:38:00
# 1           10          42         19              1   18:05:00
# 2           11          47         28              6   22:20:00
# 3            7          30         28              2   04:06:00
# 4            9          39         28              1   14:50:00
#
#   order_date_extracted
# 0           2021-07-18
# 1           2021-10-19
# 2           2021-11-28
# 3           2021-07-28
# 4           2021-09-28

# %%
#Sales vs Payment Method and Returned to Seller
data_hist=seller_sales_data[['cod', 'order_status', 'item_total']].groupby(['cod', 'order_status']).sum().reset_index()
data_hist
# Out:
#                 cod        order_status  item_total
# 0  Cash On Delivery  Delivered to buyer     22914.0
# 1  Cash On Delivery  Returned to seller         0.0
# 2            Online  Delivered to buyer     66263.0
# 3            Online  Returned to seller         0.0

# %%
sns.barplot(data=data_hist,x="cod",y="item_total",hue="order_status",)
# Out:
# <AxesSubplot:xlabel='cod', ylabel='item_total'>

# %%
print("The percentage of returned to seller for Online Sales")
print("{:.2f} %".format(data_hist.loc[3,"item_total"]/data_hist.loc[2,"item_total"]*100))
print("The percentage of returned to seller for Cash on Delivery")
print("{:.2f} %".format(data_hist.loc[1,"item_total"]/data_hist.loc[0,"item_total"]*100))
# Out:
# The percentage of returned to seller for Online Sales
# 0.00 %
# The percentage of returned to seller for Cash on Delivery
# 0.00 %

# %%
#Online payment is almost 3 times as big as cash on delivery payment method.
#Cash on delivery payment method has "Returned to seller" almost 3 times as big as online payment
#We may consider promotion for online payment method.

# %%
#Payment Method vs Shipping Fee
data_hist=seller_sales_data[['cod', 'shipping_fee','quantity']].groupby(['cod']).sum().reset_index()
data_hist["fee per quantity"]=data_hist["shipping_fee"]/data_hist["quantity"]
data_hist
# Out:
#                 cod  shipping_fee  quantity  fee per quantity
# 0  Cash On Delivery       3055.02        49         62.347347
# 1            Online       9233.50       137         67.397810

# %%
#The fee per quantity of payment methods almost the same. (2 $ difference is negligible.)
#Maybe we should consider decreasing the of for shipping with online payment Or increasing fee of shipping with cash on delivery

# %%
#Sales over Dates
data_date=seller_sales_data.groupby(["order_year","order_month"]).aggregate({"item_total":"sum"}).reset_index().sort_values(by=["order_year","order_month"])
data_date
# Out:
#    order_year  order_month  item_total
# 0        2021            6      1698.0
# 1        2021            7      2395.0
# 2        2021            8      7640.0
# 3        2021            9      9084.0
# 4        2021           10     10979.0
# 5        2021           11     13672.0
# 6        2021           12     28983.0
# 7        2022            1      7013.0
# 8        2022            2      7713.0

# %%
sns.barplot(data=data_date,x="order_year",y="item_total",hue="order_month")
plt.title("Sales vs Year")
# Out:
# Text(0.5, 1.0, 'Sales vs Year')

# %%
#ales(item_total) increases in 2021, there is an increasing trend
#After 2021 the sales are dropped, maybe people made too much expenditure at the end of the year.

# %%
plt.figure(figsize=(15,5))

lp = sns.lineplot(data=seller_sales_data,x="order_date_extracted",y="item_total",hue="order_status",markers=True,ci=0)
lp.legend(loc='upper right', bbox_to_anchor=(1.2, 1))
plt.title("Sales over years with order_status differentiation")
# Out:
# Text(0.5, 1.0, 'Sales over years with order_status differentiation')

# %%
#The sales in December is quite high, the reason might be the Christmas.
#The returned to seller order status does not change much with date.

# %%
date_december=seller_sales_data[data.order_month==12].groupby(["order_day"]).aggregate({"item_total":"sum"}).reset_index()
date_december

plt.figure(figsize=(10,4))

lp = sns.lineplot(data=date_december,x="order_day",y="item_total",markers=True,ci=0)

plt.ylabel('Total Sales')

plt.xlabel('Order Day in December month')

plt.title("Sales in December 2021")
# Out:
# Text(0.5, 1.0, 'Sales in December 2021')

# %%
#As I thought, sales increased due to Christmas.

# %%
#Correlation Analysis
seller_sales_data["cod"]=seller_sales_data["cod"].map({"Online": 0, "Cash On Delivery":1})
seller_sales_data["order_status"]=seller_sales_data["order_status"].map({"Returned to seller": 0, "Delivered to buyer":1})

# %%
feature_of_interest=["quantity","item_total","shipping_fee","cod","order_status"]
sns.heatmap(seller_sales_data[feature_of_interest].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Item_total and Quantity has medium positive correlation
#Shipping_fee and Item_total has medium positive correlation
#There is no any other signigicant correlations.
#Item total vs Quantity and Item total vs Shipping Fee correlation is as expected. The number of quantity and shipping fee increases with sales.

# %%
sns.pairplot(seller_sales_data[feature_of_interest])

# %%
#Paitplots do not show linear relationship with order_status

# %%
seller_sales_data.head(5)
# Out:
#               order_no       buyer    ship_city         ship_state  \
# 0  405-9763961-5211537         MR.   CHANDIGARH         CHANDIGARH
# 1  404-3964908-7850720       MINAM     PASIGHAT  ARUNACHAL PRADESH
# 2  171-8103182-4289117  YATIPERTIN     PASIGHAT  ARUNACHAL PRADESH
# 3  405-3171677-9557154       ACIYA  DEVARAKONDA          TELANGANA
# 4  402-8910771-1215552     SUSMITA       MUMBAI        MAHARASHTRA
#
#           sku                                        description  quantity  \
# 0  2X3C0FKNJE  100% Leather Elephant Shaped Piggy Coin Bank |...         1
# 1  DN0WDXVYOT  Women's Set of 5 Multicolor Pure Leather Singl...         1
# 2  DN0WDXVYOT  Women's Set of 5 Multicolor Pure Leather Singl...         1
# 3  AHJ3AOR7DN  Pure 100% Leather Block Print Rectangular Jewe...         1
# 4  KL7WAAZ82I  Pure Leather Sling Bag with Multiple Pockets a...         1
#
#    item_total  shipping_fee  cod  order_status  order_year  order_month  \
# 0       449.0           NaN    0             1        2021            7
# 1       449.0         60.18    0             1        2021           10
# 2       449.0         60.18    0             1        2021           11
# 3         NaN           NaN    1             1        2021            7
# 4      1099.0         84.96    0             1        2021            9
#
#    order_week  order_day  order_weekday order_time order_date_extracted
# 0          28         18              6   22:38:00           2021-07-18
# 1          42         19              1   18:05:00           2021-10-19
# 2          47         28              6   22:20:00           2021-11-28
# 3          30         28              2   04:06:00           2021-07-28
# 4          39         28              1   14:50:00           2021-09-28
